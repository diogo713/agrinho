# %% [markdown]
# <a href="https://colab.research.google.com/github/diogo713/agrinho/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aula1

# %% [markdown]
# ![codorna-e-ovos-afe.jpg](data:image/jpeg;base64,...)

# %%
ano = "IX"
print(ano,  "competição de progamação dá start")
# Out:
# IX competição de progamação dá start

# %% [markdown]
# #aula  ⭐ 🤪 🧘

# %%
 #aula2
 livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana =2 * livro ficcao + 5 * livro infantil
pomtos_totais = pontos rodrigo +pontos_ana
print(f"os pontos totais do rodrigo são {pontos_rodrigo}")
print(f"os ponto totais de ana são") {pontos_ana}")
print(f"os pontos totais de ana e rodrigo são {pontos_totais}")
# Out:
#   File "/tmp/ipython-input-2497072927.py", line 9
#     print(f"os ponto totais de ana são") {pontos_ana}*)
#                                                       ^
# SyntaxError: unmatched ')'

# %% [markdown]
# #aula 3 😖 👊 😎

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numeros_de_amigos =  int(input("Digite o números de amigo: "))
figurinhas_amigos = total_de_figurinhas // (numeros_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigos

print(f"joao recebeu {figurinhas_joao} figurinhas")
# Out:
# Digite o total de figurinhas: 9
# Digite o números de amigo: 5
# joao recebeu 2 figurinhas

# %% [markdown]
# aula4

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")

numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 70
# 70 x 1 = 70
# 70 x 2 = 140
# 70 x 3 = 210
# 70 x 4 = 280
# 70 x 5 = 350
# 70 x 6 = 420
# 70 x 7 = 490
# 70 x 8 = 560
# 70 x 9 = 630
# 70 x 10 = 700

# %% [markdown]
# aula5 🧘 😧 🛁

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} /xc  {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 5
# 5 / 1 = 5.0
# 5 / 2 = 2.5
# 5 / 3 = 1.6666666666666667
# 5 / 4 = 1.25
# 5 / 5 = 1.0
# 5 / 6 = 0.8333333333333334
# 5 / 7 = 0.7142857142857143
# 5 / 8 = 0.625
# 5 / 9 = 0.5555555555555556
# 5 / 10 = 0.5

# %% [markdown]
# aula6 chatbot⛹ ✳ ⛲

# %%
print("olá, sou seu assitente virtual")
nome = input("digite seu nome")
print(f"olá {nome}, em que posso ajudar")
respota = input("você deseja falar sobre python, javacript ou matemática:")
# Out:
# olá, sou seu assitente virtual
# digite seu nomediogo
# olá diogo, em que posso ajudar
# você deseja falar sobre python, javacript ou matemática:matematica
